# %%
print("Welcome to Assignment-1")
print('Welcome to Assignment-1')

#  Welcome to Assignment-1
# Out:
# Welcome to Assignment-1
# Welcome to Assignment-1

# %%
Num1=10
Num2=30
Add = Num1 + Num2
print("Num1 =" ,Num1)
print("Num2 =" ,Num2)
print("Add =",Add)
#  Num1= 10
#  Num2= 30
#  Add= 40
# Out:
# Num1 = 10
# Num2 = 30
# Add = 40

# %%
weight = int(input("Enter the BMI Index  "))

if weight <18:
    print("fit")
elif weight >=18 and weight < 34:
    print('weight')
elif weight >=34 and weight <50:
    print ('Very Overweight')
else:
    print("better to die")
#  Enter the BMI Index:34
#  Very Overweight
# Out:
# Enter the BMI Index   34
# Very Overweight
