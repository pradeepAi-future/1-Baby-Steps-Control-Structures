# %% [markdown]
# ### 4-Function-Assignment-1

# %% [markdown]
# # Create a class and function, and list out the items in the list

# %%
items = ['Sub-fields in AI are:','Machine Learning','Neural Networks','Vision','Robotics','Speech Processing','Natural Language Processing']

# %%
class SubfieldsInAI():
    def Subfields():
        for i in items:
            print(i)

# %%
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %% [markdown]
# # Create a function that checks whether the given number is Odd or Eve

# %%
class OddEven():
    def OddEven():
        i =int(input("Enter a number:"))
        if i%2==0:
            print (i," is Even number")
        else:   
            print("its odd number")

# %%
OddEven.OddEven()
#Enter a number: 52452
#52452 is Even number
# Out:
# Enter a number: 52452
# 52452  is Even number

# %% [markdown]
# # Create a function that tells elegibility of marriage for male and female according to their age limit like 21 for male and 18 for female

# %%
gender = str(input("Your Gender : "))
age = int(input("Your Age :  "))
# Out:
# Your Gender :  Male
# Your Age :   20

# %%
class ElegiblityForMarriage():
    def Elegible():
        if gender=="male":
            if age>20:
                print("ELIGIBLE")
        if gender=="female":     
            if age>18:
                print("ELIGIBLE")            
        else: 
            print("Not ELIGIBLE")

# %%
ElegiblityForMarriage.Elegible()
#Your Gender:Male
#Your Age:20
#NOT ELIGIBLE
# Out:
# Not ELIGIBLE

# %% [markdown]
# # calculate the percentage of your 10th mark

# %%
Subject1 =int(input())
Subject2 =int(input())
Subject3 =int(input())
Subject4 =int(input())
Subject5 =int(input())
# Out:
#  98
#  87
#  95
#  95
#  93

# %%
class FindPercent():
    def percentage():
        adds=Subject1 + Subject2 + Subject3 + Subject4 + Subject5
        add=((Subject1 + Subject2 + Subject3 + Subject4 + Subject5) /500)*100
        print("Total ",adds)
        print("Percentage ",add)

# %%
FindPercent.percentage()

#Subject1= 98
#Subject2= 87
#Subject3= 95
#Subject4= 95
#Subject5= 93
#Total : 468
#Percentage : 93.60000000000001
# Out:
# Total  468
# Percentage  93.60000000000001

# %% [markdown]
# # print area and perimeter of triangle using class and functions

# %%
Height = int(input())
Breadth = int(input())
Height1 = int(input())
Height2 = int(input())
Breadth1 = int(input())
# Out:
#  32
#  34
#  2
#  4
#  4

# %%
class triangle():
    def triangle():
        Area = (Height * Breadth) / 2
        Perimeter = Height1+Height2+Breadth1
        print("Area of Triangle: ",Area)
        print("Perimeter of Triangle: " ,Perimeter)

# %%
triangle.triangle()
#Height:32
#Breadth:34
#Area formula: (Height*Breadth)/2
#Area of Triangle: 544.0
#Height1:2
#Height2:4
#Breadth:4
#Perimeter formula: Height1+Height2+Breadth
#Perimeter of Triangle: 10
# Out:
# Area of Triangle:  544.0
# Perimeter of Triangle:  10
