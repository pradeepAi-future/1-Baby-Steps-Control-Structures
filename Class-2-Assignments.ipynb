# %%
from allfunction import multifunction

items = [
    'Sub-fields in AI are:',
    'Machine Learning',
    'Neural Networks',
    'Vision',
    'Robotics',
    'Speech Processing',
    'Natural Language Processing'
]

multifunction.Subfields(items)
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multifunction.OddEven()
# Out:
# Enter a number:  52452
# '52452 is an Even number'

# %%
gender = str(input("Your Gender : "))
age = int(input("Your Age :  "))
multifunction.Eligible(age,gender)
# Out:
# Your Gender :  male
# Your Age :   20
# 'NOT ELIGIBLE'

# %%
Subject1 =int(input())
Subject2 =int(input())
Subject3 =int(input())
Subject4 =int(input())
Subject5 =int(input())

multifunction.Percentage(Subject1,Subject2,Subject3,Subject4,Subject5)
# Out:
#  98
#  87
#  95
#  95
#  93
# Total: 468
# Percentage: 93.60000000000001

# %%
Height = int(input())
Breadth = int(input())
Height1 = int(input())
Height2 = int(input())
Breadth1 = int(input())
multifunction.Triangle(Height,Breadth,Height1,Height2,Breadth1)
# Out:
#  32
#  34
#  2
#  4
#  4
# Area of Triangle: 544.0
# Perimeter of Triangle: 10
